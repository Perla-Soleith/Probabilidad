# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 1**
#
# #Programa 2. **Máximo, mínimo, Rango y dispersión de datos**
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#Generamos 100 numeros aleatorios que representan la produccion
#en metros de tela de 100 días de la fábrica 1

fabrica1 =[]
for i in range(100):
  numero_aleatorio = round (random.uniform(50,100), 2)  #El número aleatorio puuede tener hasta dos decimales
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [52.76, 93.62, 63.44, 69.98, 83.9, 72.06, 91.57, 52.49, 59.01, 97.63, 99.22, 76.14, 60.33, 55.9, 60.78, 56.75, 69.83, 67.7, 70.05, 61.7, 91.51, 58.48, 68.45, 90.93, 77.67, 66.58, 64.41, 98.28, 74.14, 53.93, 89.16, 98.83, 67.75, 83.87, 97.9, 67.68, 83.72, 87.79, 90.26, 60.47, 56.8, 59.67, 92.62, 97.63, 59.65, 85.49, 64.25, 56.88, 53.51, 53.96, 58.25, 69.0, 67.97, 57.74, 89.66, 92.25, 57.58, 99.08, 50.57, 59.67, 87.25, 78.62, 50.65, 60.42, 85.02, 99.48, 91.14, 80.6, 92.02, 77.46, 53.53, 53.47, 63.01, 94.41, 92.59, 95.83, 88.12, 94.36, 58.03, 91.01, 64.64, 51.66, 78.87, 77.61, 59.11, 55.61, 77.2, 54.8, 67.74, 79.44, 80.72, 91.73, 91.41, 63.54, 85.25, 57.54, 53.33, 91.2, 95.52, 73.5]

# %%
#Generamos 100 numeros aleatorios que representan la produccion
#en metros de tela de 100 días de la fábrica 2

fabrica2 =[]
for i in range(100):
  numero_aleatorio = round (random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio)
print (fabrica2)
# Out:
# [79.14, 54.13, 87.57, 50.6, 99.02, 85.27, 56.88, 77.88, 88.58, 97.19, 59.41, 65.53, 72.6, 54.27, 63.62, 68.19, 63.48, 57.83, 97.78, 61.05, 70.17, 68.88, 56.56, 73.61, 81.01, 53.11, 67.05, 98.56, 54.65, 95.27, 51.82, 96.41, 62.96, 86.5, 58.53, 69.93, 87.81, 73.42, 54.93, 83.69, 60.97, 71.21, 95.51, 67.86, 82.03, 68.36, 86.06, 65.93, 84.74, 93.65, 69.5, 73.22, 59.01, 59.02, 65.02, 82.69, 93.65, 58.6, 78.46, 85.7, 95.87, 62.68, 69.82, 52.13, 56.37, 88.05, 86.49, 87.64, 83.78, 54.94, 91.36, 80.41, 81.13, 84.88, 69.81, 64.9, 78.47, 98.29, 95.86, 92.05, 60.43, 90.35, 86.97, 58.44, 92.26, 57.52, 90.32, 58.61, 88.6, 78.9, 89.61, 89.01, 89.44, 85.44, 65.76, 83.05, 79.25, 59.23, 55.31, 82.31]

# %%
maximo1 = max (fabrica1)
minimo1 = min (fabrica1)
rango1 = maximo1 - minimo1
media1 = mean (fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)
desviacion_estandar_fabrica1 = stdev (fabrica1)

print ("Estadistica descriptiva de la Fabrica 1 \n", "Media = ", media1,
       "\n Mediana = ",mediana1,
       "\n Moda =", moda1,
       "\n Maximo = ", maximo1,
       "\n Minimo = ", minimo1,
       "\n Rango = ", rango1)
print (desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media =  74.0634
#  Mediana =  71.055
#  Moda = 97.63
#  Maximo =  99.48
#  Minimo =  50.57
#  Rango =  48.910000000000004
# 15.663817163169778

# %%
maximo2 = max (fabrica2)
minimo2 = min (fabrica2)
rango2 = maximo2 - minimo2
media2 = mean (fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)
desviacion_estandar_fabrica2 = stdev (fabrica2)

print ("Estadistica descriptiva de la Fabrica 2 \n", "Media = ", media2,
       "\n Mediana = ",mediana2,
       "\n Moda =", moda2,
       "\n Maximo = ", maximo2,
       "\n Minimo = ", minimo2,
       "\n Rango = ", rango2)
print (desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media =  75.0182
#  Mediana =  75.745
#  Moda = 93.65
#  Maximo =  99.02
#  Minimo =  50.6
#  Rango =  48.419999999999995
# 14.375258021751094

# %%
plt.figure (figsize = (8,6) )
plt.hist (fabrica1, bins = 10, alpha = 0.2, color = 'purple', edgecolor = "black")
plt.axvline (media1, color = 'b', linestyle = 'dashed', linewidth = 2, label =f'Media = {media1:.2f}')
plt.axvline (mediana1, color = 'r', linestyle = 'dashed', linewidth = 2, label =f'Mediana = {mediana1:.2f}')
plt.axvline (moda1, color = 'y', linestyle = 'dashed', linewidth = 2, label =f'Moda = {media1:.2f}')
plt.axvline (media1 - desviacion_estandar_fabrica1, color = 'black', linestyle = 'dashed',
             linewidth = 2, label = f'Desv. Estandar = {desviacion_estandar_fabrica1:.2f}')
plt.axvline (media1 + desviacion_estandar_fabrica1, color = 'black', linestyle = 'dashed',
             linewidth = 2)
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title ("Producción diaria de la fábrica 1: ")
plt.legend ()

# %%
plt.figure (figsize = (8,6) )
plt.hist (fabrica2, bins = 10, alpha = 0.2, color = 'pink', edgecolor = "black")
plt.axvline (media2, color = 'b', linestyle = 'dashed', linewidth = 2, label =f'Media = {media2:.2f}')
plt.axvline (mediana2, color = 'r', linestyle = 'dashed', linewidth = 2, label =f'Mediana = {mediana2:.2f}')
plt.axvline (moda2, color = 'y', linestyle = 'dashed', linewidth = 2, label =f'Moda = {media2:.2f}')
plt.axvline (media2 - desviacion_estandar_fabrica1, color = 'black', linestyle = 'dashed',
             linewidth = 2, label = f'Desv. Estandar = {desviacion_estandar_fabrica1:.2f}')
plt.axvline (media2 + desviacion_estandar_fabrica1, color = 'black', linestyle = 'dashed',
             linewidth = 2)
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title ("Producción diaria de la fábrica 2: ")
plt.legend ()

#desviacion estandar = cuanto estan dispersos los datos

# %%
import seaborn as sns

# %%
#La densidad gráfica es una forma de visualizar la distribución de datos en
#un intervalo o periodo de tiempo continuo.
#Se basa en un histograma que usa el suavisado de kernel para trazar valores,
#lo que permite obtener distribuciones más suaves al reducir el ruido.
#Una curva de densidad muestra la ubicacion de la media y la mediana de una distrubucion

#Fabrica1
sns.histplot(x = fabrica1, kde = True, color = 'pink', kde_kws= {'bw_adjust': 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>

# %%
#Fabrica2
sns.histplot(x = fabrica2, kde = True, color = 'green', kde_kws= {'bw_adjust': 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>
