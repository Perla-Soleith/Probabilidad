# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad3/Practica1U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 3**
#
# #*Práctica 1*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import matplotlib.pyplot as plt

# %%
#Valores de la variable
x = [5, 6, 7, 8, 9, 10]
p = [0.05,0.10, 0.20, 0.30, 0.25, 0.10]

#Verificar suma = 1
print ("Suma de probabilidades: ", sum(p))

#Graficar distribucion
plt.stem(x,p)
plt.title ("Distribución de Probabilidad")
plt.xlabel ("Calificaión")
plt.ylabel ("Probabilidad")
plt.grid (True)
plt.show()
# Out:
# Suma de probabilidades:  1.0
