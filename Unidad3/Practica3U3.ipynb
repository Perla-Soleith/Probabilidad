# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad3/Practica3U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 3**
#
# #*Práctica 3*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ##Varianza y desviación estandar

# %%
x = [5, 6, 7, 8, 9, 10]
p = [0.05,0.10, 0.20, 0.30, 0.25, 0.10]

#Cacular E(X)
esperanza = 0
for i in range (len(x)):
  esperanza += x[i]* p[i]

#Calcular E(X^2)
esperanza_cuadrado = 0
for i in range (len(x)):
  esperanza_cuadrado += (x[i] ** 2) * p[i]

#Calcular la varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

#mostrar resultados
print (f"E(X) = {esperanza:.2f}")
print (f"E(X^2) = {esperanza_cuadrado:.2f}")
print (f"Varianza = {varianza:.2f}")
print (f"Desviación estandar = {desviacion:.2f}")
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviación estandar = 1.30
