# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad3/Practica6U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 3**
#
# #*Práctica 6*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %% [markdown]
# #Ejercicio 1

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
#Valores de la variable
x = [0, 1, 2, 3, 4, 5]
p = [0.10,0.25, 0.30, 0.20, 0.10, 0.05]

#Verificar suma = 1
print ("Suma de probabilidades: ", sum(p))

#Valor esperado E(X)
esperanza = 0
for i in range (len(x)):
  esperanza += x[i]* p[i]

#Calcular E(X^2)
esperanza_cuadrado = 0
for i in range (len(x)):
  esperanza_cuadrado += (x[i] ** 2) * p[i]

#Varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

print (f"Valor esperado = {esperanza:.2f}")
print (f"Varianza = {varianza:.2f}")
print (f"Desviación estandar = {desviacion:.2f}")
# Out:
# Suma de probabilidades:  1.0
# Valor esperado = 2.10
# Varianza = 1.69
# Desviación estandar = 1.30

# %%
#Funcion acumulada
F = np.cumsum(p)

for xi, fi in zip (x,F):
  print (f"F({xi}) = {fi:.2f}")

#Graficar
plt.step(x, F, where ='post')
plt.title ("Funcion de Distribución Acumulada (FDA)")
plt.xlabel("Número de células anormales")
plt.ylabel ("Probabilidad acumulada")
plt.grid(True)
plt.ylim(0,1.05)
plt.show()
# Out:
# F(0) = 0.10
# F(1) = 0.35
# F(2) = 0.65
# F(3) = 0.85
# F(4) = 0.95
# F(5) = 1.00

# %% [markdown]
# **• ¿Cuál es el promedio esperado de células anormales por muestra?**
#
# El valor esperado es 2.10
#
# **• ¿Existe mucha variabilidad entre las muestras?**
#
# Como la varianza es 1.69 y la desviación estandar es de 1.30, entonces si hay variabilidad pero no mucha.
#
# **• ¿Qué indica la función acumulada sobre la probabilidad de encontrar un número bajo o alto de células anormales?**
#
# Indica que es muy probable encontrar números bajos y menos común encontrar valores altos.
