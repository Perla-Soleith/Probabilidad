# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad4/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 4**
#
# #*Ejercicio 2*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %% [markdown]
# Una revisión de los peesos de 500 estudiantesdel ITD, evidenció que la media es de 70 kg y la desviación estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# -Cuantos estudiantes pesan menos de 75 kg.
# -Cuantos estudiantespesan menos de 62 kg.
# -Cuantos estudiantes pesan más de 79 kg.
#
# Primero necesitamos calcular la probabilidad de que un estudiante pese menos de 75kg utilizando la función

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
plt.figure(figsize=(6,4))

#Parámetros de la distribución normal
media = 70 #Media
desv_std = 4 #Desviación estándar
total_estudiantes = 500

#Variable para cálculo de la probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 75

#Primero necesitaos calcular la probailidad de que un estudiante pese menos
#de 75 kg utilizando la función de la distribución acumulativa (CDF) de la distribución normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

#Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg

print ("Probabilidad de que un estudiante pese menos de 75 kg: ", prob_menos_75kg)
print("Numero de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)

#Graficar la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf (x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between (x, y, where= (x <= peso_limite), color = 'skyblue', alpha = 0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75 kg. \n $\sigma=4$, x=500')
plt.xlabel ('Peso (kg)')
plt.ylabel ('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_15763/3159411150.py:27: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Probabilidad de que un estudiante pese menos de 75 kg. \n $\sigma=4$, x=500')
# Probabilidad de que un estudiante pese menos de 75 kg:  0.8943502263331446
# Numero de estudiantes que pesan menos de 75 kg: 447.1751131665723

# %% [markdown]
# #Cuantos estudiantes pesan menos de 62 kg.

# %%
plt.figure(figsize=(6,4))

#Parámetros de la distribución normal
media = 70 #Media
desv_std = 4 #Desviación estándar
total_estudiantes = 500

#Variable para cálculo de la probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 62

#Primero necesitaos calcular la probailidad de que un estudiante pese menos
#de 75 kg utilizando la función de la distribución acumulativa (CDF) de la distribución normal
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)

#Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg

print ("Probabilidad de que un estudiante pese menos de 62 kg: ", prob_menos_62kg)
print("Numero de estudiantes que pesan menos de 62 kg:", estudiantes_menos_62kg)

#Graficar la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf (x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between (x, y, where= (x <= peso_limite), color = 'skyblue', alpha = 0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62 kg. \n $\mu=70, $\sigma=4$, x=500')
plt.xlabel ('Peso (kg)')
plt.ylabel ('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_15763/3297794555.py:27: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Probabilidad de que un estudiante pese menos de 62 kg. \n $\mu=70, $\sigma=4$, x=500')
# Probabilidad de que un estudiante pese menos de 62 kg:  0.022750131948179195
# Numero de estudiantes que pesan menos de 62 kg: 11.375065974089598

# %% [markdown]
# #Estudiantes que pesan más de 79

# %%
plt.figure(figsize=(6,4))

#Parámetros de la distribución normal
media = 70 #Media
desv_std = 4 #Desviación estándar
peso_limite= 79 #Peso límite
total_estudiantes = 500

#Calcular la probailidad de que un estudiante pese menos o igual a 79
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)

#La probabilidad de que un estudiante pese más de 79 kg es complementaria
prob_mas_79kg = 1 - prob_menos_79kg

#Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg

print ("Probabilidad de que un estudiante pese menos de 79 kg: ", prob_mas_79kg)
print("Numero de estudiantes que pesan menos de 79 kg:", estudiantes_mas_79kg)

#Calcular la funcion de densidad de probabilidad de la distrubución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf (x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between (x, y, where= (x >= peso_limite), color = 'skyblue', alpha = 0.5)
plt.title('Probabilidad de que un estudiante pese mas de 79 kg. \n $\mu=70, $\sigma=4$, x=500')
plt.xlabel ('Peso (kg)')
plt.ylabel ('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 79 kg:  0.012224472655044671
# Numero de estudiantes que pesan menos de 79 kg: 6.112236327522336
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_15763/3844419288.py:27: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Probabilidad de que un estudiante pese mas de 79 kg. \n $\mu=70, $\sigma=4$, x=500')
