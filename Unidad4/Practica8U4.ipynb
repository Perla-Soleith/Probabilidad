# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad4/Practica8U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 4**
#
# #*Distribución T de Sudent*
# #*Práctica 8*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt

# %%
#Datos de la muestra
data = np.array([118, 125, 130, 128, 122, 135, 126, 132, 129, 120, 127, 124])
n = len (data)
media = np.mean(data)
desv_std = np.std(data, ddof = 1) #desviacion estándar muestral (ddof=1)
alpha = 0.05 #nivel de sigificancia (95% de confianza)
df = n - 1

#Valor crítico de t (dos colas)
t_critico = t.ppf (1 - alpha/2, df)

#Error estándar
error = t_critico * (desv_std / np.sqrt(n))

#Intervalo de confianza
lim_inf = media - error
lim_sup = media + error

print (f"Media muestral = {media:.2f} mmHg")
print (f"Desviacion estándar = {desv_std:.2f} mmHg")
print (f"Grados de libertad = {df}")
print (f"Valor crítico t = {t_critico:.3f}")
print (f"Intervalo de confianza 95%: [{lim_inf:.2f}, {lim_sup:.2f}] mmHg")

#Graficar
x = np.linspace (media - 3*desv_std, media + 3*desv_std, 200)
y = t.pdf((x - media) / (desv_std / np.sqrt(n)), df)

plt.figure (figsize = (8,5))
plt.plot (x, y, color = 'navy', label = 'Distribucion t de la media muestral')
plt.axvline (lim_inf, color = 'red', linestyle = '--', label = 'Limite inferior')
plt.axvline (lim_sup, color = 'red', linestyle = '--', label = 'Limite superior')
plt.axvline (media, color = 'green', linestyle = '--', label = 'Media muestral')
plt.title ("Intervalo de confianza del 95% para la media (t de Student)")
plt.xlabel ("Presiín arterial (nnHg)")
plt.ylabel ("Densidad de probabilidad")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Media muestral = 126.33 mmHg
# Desviacion estándar = 4.92 mmHg
# Grados de libertad = 11
# Valor crítico t = 2.201
# Intervalo de confianza 95%: [123.20, 129.46] mmHg
