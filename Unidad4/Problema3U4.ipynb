# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad4/Problema3U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 4**
#
# #*Problemas de Distribución Poisson y Binomial*
# #*Problema 3*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %% [markdown]
# #Es Poisson
#
# Por que en valores hay uno grande y uno muy pequeño

# %%
from scipy.stats import poisson

# %% [markdown]
# Un fabricante de podadoras para el pasto compra motores de 1 hp y 2 ciclos, en lotes de 1,000, a un proveedor.
#
# El fabricate equipa cada una de las podadoras producidas por su planta con uno de los motores.
#
# La historia muestra que la probabilidad de que cualquier motor del proveedor resulte no satisfactorio es .001.
#
#
# En un embarque de 1,000 motores, Calcular
#
# -¿cuál es la probabilidad de que ninguno sea defectuoso?,
#
# -¿cuál es la probabilidad de que tres sean defectuosos
#
# -¿cuál es la probabilidad de que cuatro sean defectuoso?

# %%
# Parámetro de Poisson
promedio_defectos = 1000 * 0.001

# Valores de x
x0 = 0
x3 = 3
x4 = 4

# Probabilidades
prob_0 = poisson.pmf(x0, promedio_defectos)
prob_3 = poisson.pmf(x3, promedio_defectos)
prob_4 = poisson.pmf(x4, promedio_defectos)

print("Probabilidad de que ninguno sea defectuoso:", prob_0)
print("Probabilidad de que 3 sean defectuosos:", prob_3)
print("Probabilidad de que 4 sean defectuosos:", prob_4)
# Out:
# Probabilidad de que ninguno sea defectuoso: 0.36787944117144233
# Probabilidad de que 3 sean defectuosos: 0.06131324019524039
# Probabilidad de que 4 sean defectuosos: 0.015328310048810101
