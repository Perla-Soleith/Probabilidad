# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad4/Practica4U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 4**
#
# #*Distribución binomial*
# #*Práctica 4*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
from scipy.stats import binom

# %%
#Parámetros de la distrubución binomial
n = 10
p = 0.10
x = 2

#Calcular la probabilidad de la variable aleatoria x = 2
probabilidad_x_2 = binom.pmf (x, n, p)

print ("La probabilidad de que la variable aleatoria X sea igual a 2 es:" , probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria X sea igual a 2 es: 0.19371024450000007
