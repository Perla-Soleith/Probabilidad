# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad5/Datos_Calificaciones_Grupo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 5**
#
# #*Regresión lineal y Correlación*
# #**PrácticaFinal**
# #**Datos Calificaciones Grupo 1**
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression # modelo de regresión Lineal
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr

# %%
df1=pd.read_csv("grupo1.csv")
df1.head()
# Out:
#    HorasEstudio  Calificacion
# 0         20.00         75.94
# 1         15.60         87.48
# 2         17.91         79.40
# 3         20.00         73.37
# 4         20.00         83.75

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HorasEstudio  50 non-null     float64
#  1   Calificacion  50 non-null     float64
# dtypes: float64(2)
# memory usage: 932.0 bytes

# %%
##df1.describe()

# %%
#Grafica
plt.hist(df1["Calificacion"], bins=10, color = 'green', alpha = 0.5)
plt.title("Histograma de Calificaciones")
plt.xlabel("Calificaciones")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# #***Regresión Lineal***

# %%
X = df1[["HorasEstudio"]]
y = df1["Calificacion"]

modelo = LinearRegression()
modelo.fit(X, y)

#La ecuacion de la línea de regresión

pendiente = modelo.coef_[0]
intercepto = modelo.intercept_

print("Pendiente (m):", pendiente)
print("Intercepto (b):", intercepto)

print(f"Ecuación de la recta:")
print(f"y = {pendiente:.2f}x + {intercepto:.2f}")
# Out:
# Pendiente (m): -0.10608151145860807
# Intercepto (b): 85.31068185245395
# Ecuación de la recta:
# y = -0.11x + 85.31

# %%
#Pearson

pearson = df1["HorasEstudio"].corr(df1["Calificacion"])

print("Coeficiente de correlación de Pearson:", pearson)
# Out:
# Coeficiente de correlación de Pearson: -0.05713334446646929

# %%
#La grafica

plt.figure(figsize=(8,5))
sns.scatterplot(
    x=df1["HorasEstudio"], y=df1["Calificacion"], color="green")
plt.plot(df1["HorasEstudio"], modelo.predict(X), color="black")
plt.title("Regresión Lineal: Horas de Estudio vs Calificación")
plt.xlabel("Horas de Estudio")
plt.ylabel("Calificación")
plt.grid(True)
plt.show()

# %% [markdown]
# #***Coeficiente de Correlación***

# %%
horas_estudio = df1["HorasEstudio"]
calificaciones = df1["Calificacion"]

# Calcular coeficiente de correlación de Pearson
coeficiente_correlacion, p_valor = pearsonr(horas_estudio, calificaciones)

# Mostrar resultados
print("Coeficiente de correlación de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlación de Pearson: -0.057133344466469324
# Valor p: 0.6935088469237538

# %% [markdown]
# #***Resultados:***
#
# **1. ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?**
#
# La pendiente es negativa (−0.11), lo que indica que al aumentar las horas de estudio, las calificaciones disminuyen ligeramente. Sin embargo, el cambio es muy pequeño.
#
#
# **2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?**
#
# El coeficiente de Pearson (−0.057) indica una relación negativa muy débil, prácticamente inexistente, entre las horas de estudio y las calificaciones.
#
# **3. ¿El modelo de regresión lineal es estadísticamente significativo?**
#
# No, porque el valor p (0.6935) es mayor que 0.05.
#
# **4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?**
#
# El modelo no es muy confiable para predecir calificaciones, ya que la relación entre las variables es muy débil.
