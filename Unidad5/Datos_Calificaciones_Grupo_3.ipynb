# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad5/Datos_Calificaciones_Grupo_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 5**
#
# #*Regresión lineal y Correlación*
# #**PrácticaFinal**
# #**Datos Calificaciones Grupo 3**
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression # modelo de regresión Lineal
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr

# %%
df3=pd.read_csv("grupo3.csv")
df3.head()
# Out:
#    HorasEstudio  Calificacion
# 0          3.79          15.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HorasEstudio  50 non-null     float64
#  1   Calificacion  50 non-null     float64
# dtypes: float64(2)
# memory usage: 932.0 bytes

# %%
df3.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.968000
# std        4.219174     23.668867
# min        3.790000     15.000000
# 25%       12.032500     61.000000
# 50%       14.600000     84.950000
# 75%       17.715000     94.375000
# max       20.000000     99.000000

# %%
#Grafica
plt.hist(df3["Calificacion"], bins=10, color = 'pink', alpha = 0.9)
plt.title("Histograma de Calificaciones")
plt.xlabel("Calificaciones")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# #***Regresión Lineal***

# %%
X = df3[["HorasEstudio"]]
y = df3["Calificacion"]

modelo = LinearRegression()
modelo.fit(X, y)

#La ecuacion de la línea de regresión

pendiente = modelo.coef_[0]
intercepto = modelo.intercept_

print("Pendiente (m):", pendiente)
print("Intercepto (b):", intercepto)

print(f"Ecuación de la recta:")
print(f"y = {pendiente:.2f}x + {intercepto:.2f}")
# Out:
# Pendiente (m): 5.285670950508442
# Intercepto (b): 0.10805051830283219
# Ecuación de la recta:
# y = 5.29x + 0.11

# %%
#Pearson

pearson = df3["HorasEstudio"].corr(df3["Calificacion"])

print("Coeficiente de correlación de Pearson:", pearson)
# Out:
# Coeficiente de correlación de Pearson: 0.9422151342073145

# %%
#La grafica

plt.figure(figsize=(8,5))
sns.scatterplot(
    x=df3["HorasEstudio"], y=df3["Calificacion"], color="red")
plt.plot(df3["HorasEstudio"], modelo.predict(X), color="black")
plt.title("Regresión Lineal: Horas de Estudio vs Calificación")
plt.xlabel("Horas de Estudio")
plt.ylabel("Calificación")
plt.grid(True)
plt.show()

# %% [markdown]
# #***Coeficiente de Correlación***

# %%
horas_estudio = df3["HorasEstudio"]
calificaciones = df3["Calificacion"]

# Calcular coeficiente de correlación de Pearson
coeficiente_correlacion, p_valor = pearsonr(horas_estudio, calificaciones)

# Mostrar resultados
print("Coeficiente de correlación de Pearson:", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlación de Pearson: 0.9422151342073145
# Valor p: 1.9341524231025033e-24

# %% [markdown]
# #***Resultados:***
#
# **1. ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?**
#
# La pendiente positiva (5.29) indica que por cada hora adicional de estudio, la calificación aumenta aproximadamente 5.29 puntos.
#
#
# **2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?**
#
# El coeficiente de Pearson (0.942) indica una relación positiva muy fuerte entre las horas de estudio y las calificaciones.
#
# **3. ¿El modelo de regresión lineal es estadísticamente significativo?**
#
# Sí, porque el valor p es mucho menor que 0.05.
#
# **4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?**
#
# El modelo es muy confiable para predecir calificaciones, ya que la relación entre las variables es muy fuerte.
