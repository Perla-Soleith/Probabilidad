# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad5/Ejercicio2U5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 5**
#
# #*Regresión lineal y Correlación*
# #*Ejercicio 2*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
from scipy.stats import pearsonr

#Datos de entrada
publicidad = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

#Calcular el coeficiente de correlacion de Pearson
coeficiente_correlacion, p_valor = pearsonr(publicidad, ganancias)

print ("Coeficiente de correlación de Pearson: ", coeficiente_correlacion)
print("Valor p:", p_valor)
# Out:
# Coeficiente de correlación de Pearson:  0.909090909090909
# Valor p: 0.012021036814425281
