# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad5/Ejercicio1U5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 5**
#
# #*Regresión lineal y Correlación*
# #*Ejercicio 1*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
from sklearn.linear_model import LinearRegression # modelo de regresión Lineal
import numpy as np

# %%
#Datos de entrada
periodos = [2018, 2019, 2020, 2021, 2022, 2023]
inversion = np.array ([2, 3, 5, 4, 11, 5]).reshape(-1, 1)
ganancias = [20, 25, 34, 30, 40, 31]

#Crear y enteenar el modelo de regresión lineal
modelo = LinearRegression()
modelo.fit (inversion, ganancias)

#Predecir la ganancia para el año 2024
ganancia_2024 = modelo.predict([[8]])

print("La ganancia esperada para el año 2024 es de: ", ganancia_2024[0])

#Coeficientes de la regresión
print ("Coeficiente de la pendiente (m): ", modelo.coef_[0])
print ("Intercepcion de la recta (b): ", modelo.intercept_)
# Out:
# La ganancia esperada para el año 2024 es de:  36.0
# Coeficiente de la pendiente (m):  2.0000000000000004
# Intercepcion de la recta (b):  20.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Definir tamaño de la figura
plt.figure(figsize=(6,4))

#Datos de entrada
inversion = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

#Dibujar el diagrama de dispersión
sns.scatterplot(x = inversion, y = ganancias)
plt.scatter (inversion, ganancias, color = 'green', marker = 'x', s = 100,
             label = 'Prediccion (8, {0:.2f})'.format(ganancias[0]))
plt.title('Diagrama de Dispersión de Inversión vs Ganancias')
plt.xlabel('Inversion (millones)')
plt.ylabel ('Ganancias (millones)')
plt.grid(True)
plt.show()

# %% [markdown]
# 2

# %%
#Datos de entrada
publicidad = np.array([2, 3, 5, 4, 11, 5]).reshape(-1,1)
ganancias = np.array([20, 25, 334, 30, 40, 31])

#Crear y entrenar el modelo de regresión lineal
modelo = LinearRegression()
modelo.fit(publicidad, ganancias)

#Predecir la ganancia para una inversión de 8 en publicidad
inversion_prediccion = np.array([[8]])
ganancia_predicha = modelo.predict (inversion_prediccion)

print ("La ganancia esperada para una inversion de 8 en publicidad es: ", ganancia_predicha	[0])
print ("Valor de la intercepción ", modelo.intercept_)

#Crear el diagrama de dispersión con la línea de regresión
plt.figure(figsize=(6, 5))
plt.scatter (publicidad, ganancias, color ='blue', label ='Datos')
plt.plot(publicidad, modelo.predict(publicidad), color ='red', label = 'Linea de regresión')
plt.scatter (inversion_prediccion, ganancia_predicha, color = 'green', marker = 'x', s = 100,
             label = 'Prediccion (8, {0:.2f})'.format(ganancia_predicha[0]))
plt.title('Pronostico de ganancias a partir de la inversión en publicidad')
plt.xlabel ('Inversión en Publicida (millones)')
plt.ylabel ('Ganancias Anuales (millones)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# La ganancia esperada para una inversion de 8 en publicidad es:  86.0
# Valor de la intercepción  70.0
