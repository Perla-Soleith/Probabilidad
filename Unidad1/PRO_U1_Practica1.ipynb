# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad1/PRO_U1_Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadística
#
# ## Unidad 1
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez
#
# ### **Programa 1: Estadística básica e Histogramas**

# %%
from statistics import *

# %%
# Lista de calificaciones del grupo de probabilidad y estadística

grupoa =[70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print (grupoa)
type(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
#Sacar la media de las calificaciones con una formula

promedio = sum(grupoa) / len (grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Utilizar la funcion mean que esta en la libreria statitics para sacar el promedio

promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333
