# %% [markdown]
# <a href="https://colab.research.google.com/github/Perla-Soleith/Probabilidad/blob/main/Unidad1/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Probabilidad y estadística***
# #**Unidad 1**
#
# #Práctica 4. **Diagramas de Cajas y bigotes*
#
# ### Facilitador: Jose Gabriel Rodiguez Rivas
#
# ### Alumno: Perla Soleith Moreno Pérez ☀

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform (50, 100), 2)
  fabrica1.append (numero_aleatorio)
print(fabrica1)
# Out:
# [64.58, 76.83, 53.77, 61.13, 84.0, 55.12, 54.57, 73.48, 58.01, 77.94, 57.36, 56.9, 57.31, 90.23, 64.04, 93.27, 74.42, 85.57, 59.93, 67.92, 66.33, 67.09, 55.0, 60.61, 86.34, 79.07, 58.89, 89.43, 95.37, 75.89, 99.13, 61.0, 83.19, 88.27, 85.45, 91.61, 91.93, 85.88, 98.88, 91.73, 68.71, 64.81, 58.09, 86.34, 79.86, 70.04, 90.16, 59.8, 69.78, 73.85, 85.69, 75.6, 98.8, 88.94, 72.53, 85.64, 75.04, 58.94, 98.22, 67.77, 52.67, 95.92, 90.22, 77.66, 73.12, 81.6, 92.65, 94.4, 54.46, 97.55, 58.76, 53.5, 84.41, 56.37, 83.54, 64.03, 72.84, 77.92, 53.8, 50.55, 91.45, 98.8, 90.86, 66.21, 50.46, 68.66, 90.77, 61.31, 88.21, 66.42, 86.7, 73.26, 64.81, 81.45, 83.41, 72.89, 75.54, 54.91, 86.9, 81.94]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round (random.uniform(40, 93), 2)
  fabrica2.append (numero_aleatorio)

print(fabrica2)
# Out:
# [82.21, 84.27, 55.38, 72.71, 40.82, 77.42, 86.44, 47.03, 68.55, 65.19, 79.12, 65.31, 65.37, 53.85, 87.37, 52.81, 67.57, 75.23, 91.98, 66.27, 72.61, 89.74, 56.88, 92.03, 59.22, 85.78, 85.13, 50.48, 84.81, 56.62, 43.04, 81.48, 88.4, 86.53, 48.21, 55.86, 50.61, 68.7, 55.8, 87.56, 89.28, 80.83, 67.48, 90.16, 48.46, 68.85, 81.28, 67.92, 76.19, 92.8, 86.44, 45.58, 66.84, 48.95, 55.88, 79.16, 57.93, 75.76, 43.93, 83.12, 82.2, 69.66, 89.04, 42.2, 69.73, 85.43, 66.04, 44.1, 64.28, 53.1, 77.91, 41.69, 41.52, 42.9, 64.13, 75.91, 70.12, 91.62, 64.53, 65.36, 82.53, 48.48, 80.41, 63.01, 53.62, 60.7, 55.78, 62.17, 82.45, 61.16, 80.51, 48.04, 63.67, 73.37, 80.4, 90.38, 77.02, 87.21, 51.97, 58.09]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
#Comparamos la producción de la fábrica 1 y 2 es un subploat

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, # Alineacion Vertical
                     vert=True,
                     patch_artist=True) # Rellenar con color
ax1.set_title('Producción fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # Alineacion Vertical
                     patch_artist=True) # Rellenar con color

ax2. set_title('Produccion fabrica 2')
plt.show()

# %%
#Insertamos un valor de 150 a la fabrica 1
#Seíra un valor atípico

fabrica1.append (150)
print (fabrica1)
# Out:
# [64.58, 76.83, 53.77, 61.13, 84.0, 55.12, 54.57, 73.48, 58.01, 77.94, 57.36, 56.9, 57.31, 90.23, 64.04, 93.27, 74.42, 85.57, 59.93, 67.92, 66.33, 67.09, 55.0, 60.61, 86.34, 79.07, 58.89, 89.43, 95.37, 75.89, 99.13, 61.0, 83.19, 88.27, 85.45, 91.61, 91.93, 85.88, 98.88, 91.73, 68.71, 64.81, 58.09, 86.34, 79.86, 70.04, 90.16, 59.8, 69.78, 73.85, 85.69, 75.6, 98.8, 88.94, 72.53, 85.64, 75.04, 58.94, 98.22, 67.77, 52.67, 95.92, 90.22, 77.66, 73.12, 81.6, 92.65, 94.4, 54.46, 97.55, 58.76, 53.5, 84.41, 56.37, 83.54, 64.03, 72.84, 77.92, 53.8, 50.55, 91.45, 98.8, 90.86, 66.21, 50.46, 68.66, 90.77, 61.31, 88.21, 66.42, 86.7, 73.26, 64.81, 81.45, 83.41, 72.89, 75.54, 54.91, 86.9, 81.94, 150]

# %%
fig, (ax1, ax2) = plt.subplots (nrows=1, ncols=2, figsize = (9,4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, # vertical box alignment
                     patch_artist=True) # fill with color
ax1.set_title('Producción fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # vertical box alignment
                     patch_artist=True) # fill with color

ax2. set_title('Producción fabrica 2')
plt.show()

# %%
#Agregamos ax1.set_ylim(0, 160) para garantizar que ambos gráficos usen la
#misma escala vertical, facilitando la comparación visual.

fig, (ax1, ax2) = plt.subplots (nrows=1, ncols=2, figsize=(9, 5))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True,  # Alineacion Vertical t
                     patch_artist=True)   # RelLenar con color
ax1. set_title('Producción fabrica 1')
ax1.set_ylim(30, 160) # Escala Uniforme de 0 a 160

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # Alineacion Vertical t
                     patch_artist=True)  # Rellenar con color

ax2.set_title('Producción fabrica 2')
ax2.set_ylim(30, 160) # Escala Uniforme de 0 a 160
plt.show()
